# %%
import requests
from bs4 import BeautifulSoup

headers = {'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:80.0) Gecko/20100101 Firefox/80.0'}
url = "https://www.amazon.co.uk/Apple-iPhone-15-128-GB/dp/B0CHX7Z69Z/ref=sr_1_1_sspa?crid=1ZNTHJFE8S6MR&keywords=iphone&qid=1698077516&sprefix=iphon%2Caps%2C659&sr=8-1-spons&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&psc=1"

# Send a GET request to the URL
response = requests.get(url, headers=headers)

# Parse the HTML content
soup = BeautifulSoup(response.content, 'html.parser')

# Find the element with the specified ID and class
product_title_element = soup.find('span', {'id': 'productTitle', 'class': 'a-size-large product-title-word-break'})

# Get the text from the element
product_title = product_title_element.get_text(strip=True)

print(product_title)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_61065/579749943.py in <module>
#      15
#      16 # Get the text from the element
# ---> 17 product_title = product_title_element.get_text(strip=True)
#      18
#      19 print(product_title)
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
import requests
from bs4 import BeautifulSoup

# URL of the page containing the element
headers = {'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:80.0) Gecko/20100101 Firefox/80.0'}
url = 'https://www.amazon.co.uk/Apple-iPhone-15-128-GB/dp/B0CHX7Z69Z/ref=sr_1_1_sspa?crid=1ZNTHJFE8S6MR&keywords=iphone&qid=1698077516&sprefix=iphon%2Caps%2C659&sr=8-1-spons&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&th=1'  # Replace with your URL

# Send a GET request to the URL
response = requests.get(url,headers=headers)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find the element with the specified ID and class
    product_title_element = soup.find('span', {'class': 'a-price-whole'})

    if product_title_element:
        # Get the text content
        product_title = product_title_element.get_text(strip=True)
        print(product_title)
    else:
        print("Element not found")
else:
    print(f"Error: Status code {response.status_code}")
# Out:
# Element not found

# %%
response
# Out:
# <Response [200]>

# %%
import asyncio
from playwright.async_api import async_playwright

async def scrape_amazon_product_title(url):
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        # Create a new browser context and set the user agent
        context = await browser.new_context(user_agent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3")
        page = await context.new_page()
        await page.goto(url)
        product_title_element = await page.query_selector("#productTitle")
        product_title = await product_title_element.text_content()
        product_title = product_title.strip() if product_title else "Title not found"
        print("Product Title:", product_title)
        await browser.close()

url = "https://www.amazon.co.uk/Apple-iPhone-15-128-GB/dp/B0CHX7Z69Z/ref=sr_1_1_sspa?crid=1ZNTHJFE8S6MR&keywords=iphone&qid=1698077516&sprefix=iphon%2Caps%2C659&sr=8-1-spons&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&th=1"
await scrape_amazon_product_title(url)
# Out:
# Product Title: Apple iPhone 15 (128 GB) - Green

# %%
import asyncio
from playwright.async_api import async_playwright

async def scrape_amazon_product_title_and_price(url):
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        # Create a new browser context and set the user agent
        context = await browser.new_context(user_agent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3")
        page = await context.new_page()
        await page.goto(url)
        
        # Scrape the product title
        product_title_element = await page.query_selector("#productTitle")
        product_title = await product_title_element.text_content()
        product_title = product_title.strip() if product_title else "Title not found"
        
        # Scrape the product price
        product_price_whole_element = await page.query_selector(".a-price-whole")
        product_price_whole = await product_price_whole_element.text_content() if product_price_whole_element else ""
        product_price_decimal_element = await page.query_selector(".a-price-decimal")
        product_price_decimal = await product_price_decimal_element.text_content() if product_price_decimal_element else ""
        product_price = product_price_whole + product_price_decimal
        product_price = product_price.strip() if product_price else "Price not found"
        
        print("Product Title:", product_title)
        print("Product Price:", product_price)
        await browser.close()

url = "https://www.amazon.co.uk/Apple-iPhone-15-128-GB/dp/B0CHX7Z69Z/ref=sr_1_1_sspa?crid=1ZNTHJFE8S6MR&keywords=iphone&qid=1698077516&sprefix=iphon%2Caps%2C659&sr=8-1-spons&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&th=1"
await scrape_amazon_product_title_and_price(url)
# Out:
# /Users/hasanenesguray/opt/anaconda3/lib/python3.9/codeop.py:143: RuntimeWarning: coroutine 'scrape_amazon_product_title' was never awaited
#   codeob = compile(source, filename, symbol, self.flags, True)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# Product Title: Apple iPhone 15 (128 GB) - Green
# Product Price: 799..

# %%
import asyncio
from playwright.async_api import async_playwright

async def scrape_amazon_product_details(url):
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        context = await browser.new_context(user_agent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3")
        page = await context.new_page()
        await page.goto(url)
        
        product_title_element = await page.query_selector("#productTitle")
        product_title = await product_title_element.text_content()
        product_title = product_title.strip() if product_title else "Title not found"
        
        product_price_whole_element = await page.query_selector(".a-price-whole")
        product_price_whole = await product_price_whole_element.text_content() if product_price_whole_element else ""
        product_price_decimal_element = await page.query_selector(".a-price-decimal")
        product_price_decimal = await product_price_decimal_element.text_content() if product_price_decimal_element else ""
        product_price = product_price_whole + product_price_decimal
        product_price = product_price.strip() if product_price else "Price not found"
        
        # Scrape product details from the table
        product_details = {}
        table_rows = await page.query_selector_all("tbody > tr")
        for row in table_rows:
            label_element = await row.query_selector("td.a-span3 > span")
            value_element = await row.query_selector("td.a-span9 > span")
            label = await label_element.text_content() if label_element else "Label not found"
            value = await value_element.text_content() if value_element else "Value not found"
            product_details[label.strip()] = value.strip()

        print("Product Title:", product_title)
        print("Product Price:", product_price)
        print("Product Details:", product_details)
        await browser.close()

url = "https://www.amazon.co.uk/Apple-iPhone-15-128-GB/dp/B0CHX7Z69Z/ref=sr_1_1_sspa?crid=1ZNTHJFE8S6MR&keywords=iphone&qid=1698077516&sprefix=iphon%2Caps%2C659&sr=8-1-spons&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&th=1"
await scrape_amazon_product_details(url)
# Out:
# Product Title: Apple iPhone 15 (128 GB) - Green
# Product Price: 799..
# Product Details: {'Label not found': 'Value not found', 'Brand': 'Apple', 'Model name': 'iPhone 15', 'Wireless carrier': 'Unlocked for All Carriers', 'Operating system': 'iOS 16', 'Cellular technology': '5G', 'Memory storage capacity': '128 GB', 'Connectivity technology': 'USB', 'Colour': 'Green', 'Screen size': '6.1 Inches', 'Wireless network technology': 'Wi-Fi'}

# %%
import asyncio
from playwright.async_api import async_playwright

async def scrape_amazon_product_details(url):
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        context = await browser.new_context(user_agent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3")
        page = await context.new_page()
        await page.goto(url)
        
        product_title_element = await page.query_selector("#productTitle")
        product_title = await product_title_element.text_content()
        product_title = product_title.strip() if product_title else "Title not found"
        
        product_price_whole_element = await page.query_selector(".a-price-whole")
        product_price_whole = await product_price_whole_element.text_content() if product_price_whole_element else ""
        product_price_decimal_element = await page.query_selector(".a-price-decimal")
        product_price_decimal = await product_price_decimal_element.text_content() if product_price_decimal_element else ""
        product_price = product_price_whole + product_price_decimal
        product_price = product_price.strip() if product_price else "Price not found"
        
        # Scrape rating
        rating_element = await page.query_selector("span[data-hook='rating-out-of-text']")
        rating = await rating_element.text_content() if rating_element else "Rating not found"
        rating = rating.strip() if rating else "Rating not found"
        
        # Scrape product details from the table
        product_details = {}
        table_rows = await page.query_selector_all("tbody > tr")
        for row in table_rows:
            label_element = await row.query_selector("td.a-span3 > span")
            value_element = await row.query_selector("td.a-span9 > span")
            label = await label_element.text_content() if label_element else "Label not found"
            value = await value_element.text_content() if value_element else "Value not found"
            product_details[label.strip()] = value.strip()

        print("Product Title:", product_title)
        print("Product Price:", product_price)
        print("Product Rating:", rating)
        print("Product Details:", product_details)
        await browser.close()

url = "https://www.amazon.co.uk/Apple-iPhone-15-128-GB/dp/B0CHX7Z69Z/ref=sr_1_1_sspa?crid=1ZNTHJFE8S6MR&keywords=iphone&qid=1698077516&sprefix=iphon%2Caps%2C659&sr=8-1-spons&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&th=1"
await scrape_amazon_product_details(url)
# Out:
# Product Title: Apple iPhone 15 (128 GB) - Green
# Product Price: 799..
# Product Rating: 4.4 out of 5
# Product Details: {'Label not found': 'Value not found', 'Brand': 'Apple', 'Model name': 'IPhone 15', 'Wireless carrier': 'Unlocked for All Carriers', 'Operating system': 'IOS 16', 'Cellular technology': '5G', 'Memory storage capacity': '128 GB', 'Connectivity technology': 'USB', 'Colour': 'Green', 'Screen size': '6.1 Inches', 'Wireless network technology': 'Wi-Fi'}
# /Users/hasanenesguray/opt/anaconda3/lib/python3.9/asyncio/base_events.py:771: RuntimeWarning: coroutine 'scrape_amazon_product_title' was never awaited
#   handle = events.Handle(callback, args, self, context)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %%
import asyncio
from playwright.async_api import async_playwright

async def scrape_amazon_product_details(url):
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        context = await browser.new_context(user_agent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3")
        page = await context.new_page()
        await page.goto(url)
        
        product_title_element = await page.query_selector("#productTitle")
        product_title = await product_title_element.text_content()
        product_title = product_title.strip() if product_title else "Title not found"
        
        product_price_whole_element = await page.query_selector(".a-price-whole")
        product_price_whole = await product_price_whole_element.text_content() if product_price_whole_element else ""
        product_price_decimal_element = await page.query_selector(".a-price-decimal")
        product_price_decimal = await product_price_decimal_element.text_content() if product_price_decimal_element else ""
        product_price = product_price_whole + product_price_decimal
        product_price = product_price.strip() if product_price else "Price not found"
        
        rating_element = await page.query_selector("span[data-hook='rating-out-of-text']")
        rating = await rating_element.text_content() if rating_element else "Rating not found"
        rating = rating.strip() if rating else "Rating not found"
        
        comments_count_element = await page.query_selector("span[data-hook='total-review-count']")
        comments_count = await comments_count_element.text_content() if comments_count_element else "Comments count not found"
        comments_count = comments_count.strip() if comments_count else "Comments count not found"
        
        reviews_link_element = await page.query_selector("a[data-hook='see-all-reviews-link-foot']")
        reviews_link = await reviews_link_element.get_attribute("href") if reviews_link_element else "Reviews link not found"
        reviews_link = "https://www.amazon.co.uk" + reviews_link if reviews_link != "Reviews link not found" else reviews_link
        
        product_details = {}
        table_rows = await page.query_selector_all("tbody > tr")
        for row in table_rows:
            label_element = await row.query_selector("td.a-span3 > span")
            value_element = await row.query_selector("td.a-span9 > span")
            label = await label_element.text_content() if label_element else "Label not found"
            value = await value_element.text_content() if value_element else "Value not found"
            product_details[label.strip()] = value.strip()

        print("Product Title:", product_title)
        print("Product Price:", product_price)
        print("Product Rating:", rating)
        print("Comments Count:", comments_count)
        print("Reviews Link:", reviews_link)
        print("Product Details:", product_details)
        await browser.close()

url = "https://www.amazon.co.uk/Apple-iPhone-15-128-GB/dp/B0CHX7Z69Z/ref=sr_1_1_sspa?crid=1ZNTHJFE8S6MR&keywords=iphone&qid=1698077516&sprefix=iphon%2Caps%2C659&sr=8-1-spons&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&th=1"
await scrape_amazon_product_details(url)
# Out:
# Product Title: Apple iPhone 15 (128 GB) - Green
# Product Price: 799..
# Product Rating: 4.4 out of 5
# Comments Count: 191 global ratings
# Reviews Link: https://www.amazon.co.uk/Apple-iPhone-15-128-GB/product-reviews/B0CHX7Z69Z/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# Product Details: {'Label not found': 'Value not found', 'Brand': 'Apple', 'Model name': 'iPhone 15', 'Wireless carrier': 'Unlocked for All Carriers', 'Operating system': 'iOS 16', 'Cellular technology': '5G', 'Memory storage capacity': '128 GB', 'Connectivity technology': 'USB', 'Colour': 'Green', 'Screen size': '6.1 Inches', 'Wireless network technology': 'Wi-Fi'}

# %%
import asyncio
from playwright.async_api import async_playwright
import pandas as pd

async def scrape_amazon_product_details(url):
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        context = await browser.new_context(user_agent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3")
        page = await context.new_page()
        await page.goto(url)
        
        product_title_element = await page.query_selector("#productTitle")
        product_title = await product_title_element.text_content()
        product_title = product_title.strip() if product_title else "Title not found"
        
        product_price_whole_element = await page.query_selector(".a-price-whole")
        product_price_whole = await product_price_whole_element.text_content() if product_price_whole_element else ""
        product_price_decimal_element = await page.query_selector(".a-price-decimal")
        product_price_decimal = await product_price_decimal_element.text_content() if product_price_decimal_element else ""
        product_price = product_price_whole + product_price_decimal
        product_price = product_price.strip() if product_price else "Price not found"
        
        rating_element = await page.query_selector("span[data-hook='rating-out-of-text']")
        rating = await rating_element.text_content() if rating_element else "Rating not found"
        rating = rating.strip() if rating else "Rating not found"
        
        comments_count_element = await page.query_selector("span[data-hook='total-review-count']")
        comments_count = await comments_count_element.text_content() if comments_count_element else "Comments count not found"
        comments_count = comments_count.strip() if comments_count else "Comments count not found"
        
        reviews_link_element = await page.query_selector("a[data-hook='see-all-reviews-link-foot']")
        reviews_link = await reviews_link_element.get_attribute("href") if reviews_link_element else "Reviews link not found"
        reviews_link = "https://www.amazon.co.uk" + reviews_link if reviews_link != "Reviews link not found" else reviews_link
        
        product_details = {}
        table_rows = await page.query_selector_all("tbody > tr")
        for row in table_rows:
            label_element = await row.query_selector("td.a-span3 > span")
            value_element = await row.query_selector("td.a-span9 > span")
            label = await label_element.text_content() if label_element else "Label not found"
            value = await value_element.text_content() if value_element else "Value not found"
            product_details[label.strip()] = value.strip()

        # Creating a dictionary for the product information
        product_info = {
            "Product Title": [product_title],
            "Product Price": [product_price],
            "Product Rating": [rating],
            "Comments Count": [comments_count],
            "Reviews Link": [reviews_link]
        }
        
        # Combining product details with product information
        #product_data = {**product_info, **product_details}
        
        # Creating a DataFrame
        #df = pd.DataFrame(product_data)
        await browser.close()
        
        return product_data

url = "https://www.amazon.co.uk/Apple-iPhone-15-128-GB/dp/B0CHX7Z69Z/ref=sr_1_1_sspa?crid=1ZNTHJFE8S6MR&keywords=iphone&qid=1698077516&sprefix=iphon%2Caps%2C659&sr=8-1-spons&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&th=1"
df = await scrape_amazon_product_details(url)
df
# Out:
#                       Product Title Product Price Product Rating  \
# 0  Apple iPhone 15 (128 GB) - Green         799..   4.4 out of 5
#
#        Comments Count                                       Reviews Link  \
# 0  191 global ratings  https://www.amazon.co.uk/Apple-iPhone-15-128-G...
#
#    Label not found  Brand Model name           Wireless carrier  \
# 0  Value not found  Apple  iPhone 15  Unlocked for All Carriers
#
#   Operating system Cellular technology Memory storage capacity  \
# 0           iOS 16                  5G                  128 GB
#
#   Connectivity technology Colour Screen size Wireless network technology
# 0                     USB  Green  6.1 Inches                       Wi-Fi

# %%
import asyncio
from playwright.async_api import async_playwright
import pandas as pd

async def scrape_amazon_product_details(url):
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        context = await browser.new_context(user_agent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3")
        page = await context.new_page()
        await page.goto(url)
        
        product_title_element = await page.query_selector("#productTitle")
        product_title = await product_title_element.text_content()
        product_title = product_title.strip() if product_title else "Title not found"
        
        product_price_whole_element = await page.query_selector(".a-price-whole")
        product_price_whole = await product_price_whole_element.text_content() if product_price_whole_element else ""
        product_price_decimal_element = await page.query_selector(".a-price-decimal")
        product_price_decimal = await product_price_decimal_element.text_content() if product_price_decimal_element else ""
        product_price = product_price_whole + product_price_decimal
        product_price = product_price.strip() if product_price else "Price not found"
        
        rating_element = await page.query_selector("span[data-hook='rating-out-of-text']")
        rating = await rating_element.text_content() if rating_element else "Rating not found"
        rating = rating.strip() if rating else "Rating not found"
        
        comments_count_element = await page.query_selector("span[data-hook='total-review-count']")
        comments_count = await comments_count_element.text_content() if comments_count_element else "Comments count not found"
        comments_count = comments_count.strip() if comments_count else "Comments count not found"
        
        reviews_link_element = await page.query_selector("a[data-hook='see-all-reviews-link-foot']")
        reviews_link = await reviews_link_element.get_attribute("href") if reviews_link_element else "Reviews link not found"
        reviews_link = "https://www.amazon.co.uk" + reviews_link if reviews_link != "Reviews link not found" else reviews_link
        
        product_details = {}
        table_rows = await page.query_selector_all("tbody > tr")
        for row in table_rows:
            label_element = await row.query_selector("td.a-span3 > span")
            value_element = await row.query_selector("td.a-span9 > span")
            label = await label_element.text_content() if label_element else "Label not found"
            value = await value_element.text_content() if value_element else "Value not found"
            product_details[label.strip()] = value.strip()

        # Creating a dictionary for the product information
        product_info = {
            "Product Title": [product_title],
            "Product Price": [product_price],
            "Product Rating": [rating],
            "Comments Count": [comments_count],
            "Reviews Link": [reviews_link]
        }
        
        # Combining product details with product information
        product_data = {**product_info, **product_details}
        
        # Creating a DataFrame
        df = pd.DataFrame(product_data)
        await browser.close()
        
        return df

url = "https://www.amazon.co.uk/Apple-iPhone-15-128-GB/dp/B0CHX7Z69Z/ref=sr_1_1_sspa?crid=1ZNTHJFE8S6MR&keywords=iphone&qid=1698077516&sprefix=iphon%2Caps%2C659&sr=8-1-spons&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&th=1"
df = await scrape_amazon_product_details(url)
df




async def scrape_amazon_reviews(reviews_url, product_info):
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        await page.goto(reviews_url)

        review_elements = await page.query_selector_all(".a-section.celwidget")

        reviews_data = []
        for review_element in review_elements:
            review = {}

            # Author
            review_author_element = await review_element.query_selector(".a-profile-name")
            review['author'] = await review_author_element.text_content() if review_author_element else None

            # Rating
            review_rating_element = await review_element.query_selector(".review-rating")
            review['rating'] = await review_rating_element.text_content() if review_rating_element else None

            # Title
            review_title_element = await review_element.query_selector(".review-title")
            review['title'] = await review_title_element.text_content() if review_title_element else None

            # Date
            review_date_element = await review_element.query_selector(".review-date")
            review['date'] = await review_date_element.text_content() if review_date_element else None

            # Review Body
            review_body_element = await review_element.query_selector(".review-text")
            review['body'] = await review_body_element.text_content() if review_body_element else None

            # Size and Color
            review_format_element = await review_element.query_selector(".review-format-strip")
            review['format'] = await review_format_element.text_content() if review_format_element else None

            # Merging product info with the review info for each review
            merged_data = {**product_info, **review}
            reviews_data.append(review)

        await browser.close()

    return reviews_data

# Sample product info, replace this with your actual product info
product_info = {
    'Name': 'iPhone 15',
    'Price': '£999',
    'Rating': '4.4 out of 5',
    'Number of Reviews': '191 global ratings',
    'Reviews Link': '/product-reviews/B0CHX7Z69Z/ref=cm_cr_othr_d_show_all_btm?ie=UTF8&reviewerType=all_reviews'
}

reviews_url = f"https://www.amazon.co.uk/product-reviews/B0CHX7Z69Z/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=2"
df = await scrape_amazon_reviews(reviews_url, product_info)
#df = df.dropna(subset=['body']).drop_duplicates()
df
# Out:
# []

# %%
import asyncio
from playwright.async_api import async_playwright
import pandas as pd

async def scrape_amazon_product_details(url):
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        context = await browser.new_context(user_agent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3")
        page = await context.new_page()
        await page.goto(url)
        
        product_title_element = await page.query_selector("#productTitle")
        product_title = await product_title_element.text_content()
        product_title = product_title.strip() if product_title else "Title not found"
        
        product_price_whole_element = await page.query_selector(".a-price-whole")
        product_price_whole = await product_price_whole_element.text_content() if product_price_whole_element else ""
        product_price_decimal_element = await page.query_selector(".a-price-decimal")
        product_price_decimal = await product_price_decimal_element.text_content() if product_price_decimal_element else ""
        product_price = product_price_whole + product_price_decimal
        product_price = product_price.strip() if product_price else "Price not found"
        
        rating_element = await page.query_selector("span[data-hook='rating-out-of-text']")
        rating = await rating_element.text_content() if rating_element else "Rating not found"
        rating = rating.strip() if rating else "Rating not found"
        
        comments_count_element = await page.query_selector("span[data-hook='total-review-count']")
        comments_count = await comments_count_element.text_content() if comments_count_element else "Comments count not found"
        comments_count = comments_count.strip() if comments_count else "Comments count not found"
        
        reviews_link_element = await page.query_selector("a[data-hook='see-all-reviews-link-foot']")
        reviews_link = await reviews_link_element.get_attribute("href") if reviews_link_element else "Reviews link not found"
        reviews_link = "https://www.amazon.co.uk" + reviews_link if reviews_link != "Reviews link not found" else reviews_link
        
        product_details = {}
        table_rows = await page.query_selector_all("tbody > tr")
        for row in table_rows:
            label_element = await row.query_selector("td.a-span3 > span")
            value_element = await row.query_selector("td.a-span9 > span")
            label = await label_element.text_content() if label_element else "Label not found"
            value = await value_element.text_content() if value_element else "Value not found"
            product_details[label.strip()] = value.strip()

        # Creating a dictionary for the product information
        product_info = {
            "Product Title": [product_title][0],
            "Product Price": [product_price][0],
            "Product Rating": [rating][0],
            "Comments Count": [comments_count][0],
            "Reviews Link": [reviews_link][0]
        }
        
        # Combining product details with product information
        product_data = {**product_info, **product_details}
        
        # Creating a DataFrame
        #df = pd.DataFrame(product_data)
        await browser.close()
        
        return product_data

url = "https://www.amazon.co.uk/Apple-iPhone-15-128-GB/dp/B0CHX7Z69Z/ref=sr_1_1_sspa?crid=1ZNTHJFE8S6MR&keywords=iphone&qid=1698077516&sprefix=iphon%2Caps%2C659&sr=8-1-spons&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&th=1"
product_info = await scrape_amazon_product_details(url)
product_info
# Out:
# {'Product Title': 'Apple iPhone 15 (128 GB) - Green',
#  'Product Price': '799..',
#  'Product Rating': '4.4 out of 5',
#  'Comments Count': '198 global ratings',
#  'Reviews Link': 'https://www.amazon.co.uk/Apple-iPhone-15-128-GB/product-reviews/B0CHX7Z69Z/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
#  'Label not found': 'Value not found',
#  'Brand': 'Apple',
#  'Model name': 'iPhone 15',
#  'Wireless carrier': 'Unlocked for All Carriers',
#  'Operating system': 'iOS 16',
#  'Cellular technology': '5G',
#  'Memory storage capacity': '128 GB',
#  'Connectivity technology': 'USB',
#  'Colour': 'Green',
#  'Screen size': '6.1 Inches',
#  'Wireless network technology': 'Wi-Fi'}

# %%
product_info['Reviews Link']
# Out:
# 'https://www.amazon.co.uk/Apple-iPhone-15-128-GB/product-reviews/B0CHX7Z69Z/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews'

# %%
import asyncio
from playwright.async_api import async_playwright
import time

async def scrape_links(url):
    async with async_playwright() as p:
        browser = await p.chromium.launch()
        page = await browser.new_page()
        await page.goto(url)
        
        links = await page.query_selector_all('a.a-link-normal.s-underline-text.s-underline-link-text.s-link-style.a-text-normal')
        hrefs = [await link.get_attribute('href') for link in links if await link.get_attribute('href') is not None]
        
        await browser.close()
        return hrefs
hrefs = list()
for i in range(400):
    url = 'https://www.amazon.co.uk/s?k=iphone&i=electronics&rh=n%3A560820&page=2&qid=1698812264&ref=sr_pg_'+str(i+1)
    temp = await scrape_links(url)
    temp = list(set(temp))
    hrefs = hrefs + temp
    time.sleep(2)
hrefs

# %%
import asyncio
from playwright.async_api import async_playwright
import pandas as pd

async def scrape_amazon_product_details(url):
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        context = await browser.new_context(user_agent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3")
        page = await context.new_page()
        await page.goto(url)
        
        product_title_element = await page.query_selector("#productTitle")
        product_title = await product_title_element.text_content()
        product_title = product_title.strip() if product_title else "Title not found"
        
        product_price_whole_element = await page.query_selector(".a-price-whole")
        product_price_whole = await product_price_whole_element.text_content() if product_price_whole_element else ""
        product_price_decimal_element = await page.query_selector(".a-price-decimal")
        product_price_decimal = await product_price_decimal_element.text_content() if product_price_decimal_element else ""
        product_price = product_price_whole + product_price_decimal
        product_price = product_price.strip() if product_price else "Price not found"
        
        rating_element = await page.query_selector("span[data-hook='rating-out-of-text']")
        rating = await rating_element.text_content() if rating_element else "Rating not found"
        rating = rating.strip() if rating else "Rating not found"
        
        comments_count_element = await page.query_selector("span[data-hook='total-review-count']")
        comments_count = await comments_count_element.text_content() if comments_count_element else "Comments count not found"
        comments_count = comments_count.strip() if comments_count else "Comments count not found"
        
        reviews_link_element = await page.query_selector("a[data-hook='see-all-reviews-link-foot']")
        reviews_link = await reviews_link_element.get_attribute("href") if reviews_link_element else "Reviews link not found"
        reviews_link = "https://www.amazon.co.uk" + reviews_link if reviews_link != "Reviews link not found" else reviews_link
        
        product_details = {}
        table_rows = await page.query_selector_all("tbody > tr")
        for row in table_rows:
            label_element = await row.query_selector("td.a-span3 > span")
            value_element = await row.query_selector("td.a-span9 > span")
            label = await label_element.text_content() if label_element else "Label not found"
            value = await value_element.text_content() if value_element else "Value not found"
            product_details[label.strip()] = value.strip()

        # Creating a dictionary for the product information
        product_info = {
            "Product Title": [product_title][0],
            "Product Price": [product_price][0],
            "Product Rating": [rating][0],
            "Comments Count": [comments_count][0],
            "Reviews Link": [reviews_link][0]
        }
        
        # Combining product details with product information
        product_data = {**product_info, **product_details}
        
        # Creating a DataFrame
        #df = pd.DataFrame(product_data)
        await browser.close()
        
        return product_data

async def scrape_amazon_reviews(reviews_url, product_info):
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        await page.goto(reviews_url)

        review_elements = await page.query_selector_all(".a-section.celwidget")

        reviews_data = []
        for review_element in review_elements:
            review = {}

            # Author
            review_author_element = await review_element.query_selector(".a-profile-name")
            review['Review - Author'] = await review_author_element.text_content() if review_author_element else None

            # Rating
            review_rating_element = await review_element.query_selector(".review-rating")
            review['Review - Rating'] = await review_rating_element.text_content() if review_rating_element else None

            # Title
            review_title_element = await review_element.query_selector(".review-title")
            review['Review - Title'] = await review_title_element.text_content() if review_title_element else None

            # Date
            review_date_element = await review_element.query_selector(".review-date")
            review['Review - Date'] = await review_date_element.text_content() if review_date_element else None

            # Review Body
            review_body_element = await review_element.query_selector(".review-text")
            review['Review - Body'] = await review_body_element.text_content() if review_body_element else None

            # Size and Color
            review_format_element = await review_element.query_selector(".review-format-strip")
            review['Review - Format'] = await review_format_element.text_content() if review_format_element else None

            # Merging product info with the review info for each review
            merged_data = {**product_info, **review}
            reviews_data.append(merged_data)

        await browser.close()

    return pd.DataFrame(reviews_data)
for href in range(len(hrefs)):
    print(str(href+1) + " / " + str(len(hrefs)))
    url="https://www.amazon.co.uk"+hrefs['href']
    product_info = await scrape_amazon_product_details(url)
    reviews_url = product_info['Reviews Link']
    temp_df = await scrape_amazon_reviews(reviews_url, product_info)
    temp_df['Search'] = 'iPhone'
    df = pd.concat([df, temp_df], ignore_index=True)
    df = df.dropna(subset=['Review - Body']).drop_duplicates(subset=['Review - Body'])
    df.to_csv('amazon_comments.csv', index=False)
df
