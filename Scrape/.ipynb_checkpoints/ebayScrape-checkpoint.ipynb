# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.amazon.co.uk/Apple-iPhone-15-128-GB/dp/B0CHX7Z69Z/ref=sr_1_1_sspa?crid=1ZNTHJFE8S6MR&keywords=iphone&qid=1698077516&sprefix=iphon%2Caps%2C659&sr=8-1-spons&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&psc=1"

# Send a GET request to the URL
response = requests.get(url)

# Parse the HTML content
soup = BeautifulSoup(response.content, 'html.parser')

# Find the element with the specified ID and class
product_title_element = soup.find('span', {'id': 'productTitle', 'class': 'a-size-large product-title-word-break'})

# Get the text from the element
product_title = product_title_element.get_text(strip=True)

print(product_title)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_37627/2455170758.py in <module>
#      14
#      15 # Get the text from the element
# ---> 16 product_title = product_title_element.get_text(strip=True)
#      17
#      18 print(product_title)
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.ebay.co.uk/itm/404561506329?epid=7052775937&hash=item5e31beb019:g:pjUAAOSwD4hlMjfM&amdata=enc%3AAQAIAAAA0DS%2BHBZXg%2B91AMPMNuaKmvaXfniK6GThHnlzWqGxFS00G3AeFiUwVKcEPoUKKMQaoWzrd%2FEarjQMhsp02qIWlAHYdeefYx6%2FngteWe%2FMIKqtkb2NrYv0tA%2F9SSWVw4fCf96eLMjYZ3EtwnCBhcCsG9VSaLciCNF1lCOhHmlE1Jjw1BpZN8eE87c1hItIlCmBeaCPABvpqR7xsM7Z9I4fJI2GTn4q7Rgw30dAEO5m3Y3O%2FVyPIYCYZHtnR7JUtOF5nAxRRopJpAwBrAszQsR6eqI%3D%7Ctkp%3ABFBMqN6U1eti"

# Send a GET request to the URL
response = requests.get(url)

# Parse the HTML content
soup = BeautifulSoup(response.content, 'html.parser')

# Find the element with the specified class
product_title_element = soup.find('span', {'class': 'ux-textspans'})

# Get the text from the element
product_title = product_title_element.get_text(strip=True)

print(product_title)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Define the URLs
urls = [
    "https://www.ebay.co.uk/itm/175983176213?epid=5041723784&hash=item28f96a2a15%3Ag%3Af-wAAOSwuDNlJE%7E0&amdata=enc%3AAQAIAAAA4Knm7c%2Ftvy8jUtqlGqsygnKynqPjDH%2BpjK4zApHhuCfNTt6a5vxvimSEGIBCUW8Wspe5eN0J8his5jWcyjqsDID1c5I0ADmXFH4NfBNw49aB6LcCxtLxCC0Y0fRzgprjm8L6%2BTWsP8GPksLLPuGeWbibJAAK7T5gwF%2FIjmjvylC37pnr5xCZRSGDm%2FaSdtbjL0P3hiM3%2FX%2FL90rSBHTPwsKZvfi71cifhx0kT1XynatBP8PvJSOEn59h0PwrlY6b8dtQ4%2BtwBVXXG%2B2DxxBpEc0C5%2BJk1V9Hm0eidky%2FwiY4%7Ctkp%3ABk9SR5Sn5uvrYg&LH_ItemCondition=1000"
]

# Initialize an empty list to store the results
results = []

for url in urls:
    # Send a GET request to the URL
    response = requests.get(url)
    
    # Parse the HTML content
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find the elements
    product_title_element = soup.find('span', {'class': 'ux-textspans ux-textspans--BOLD'})
    condition_element = soup.find('span', {'data-testid': 'ux-textual-display'})
    price_element = soup.find('div', {'data-testid': 'x-price-primary'})
    seller_element = soup.find('span', {'class': 'ux-textspans ux-textspans--PSEUDOLINK ux-textspans--BOLD'})
    reviews_element = soup.find('div', {'class': 'x-review-details__allreviews'})
    
    # Get the text from the elements
    product_title = product_title_element.get_text(strip=True)
    condition = condition_element.find(class_="ux-textspans").text.strip()
    price = price_element.find(class_="ux-textspans").text.strip()
    seller = seller_element.get_text(strip=True)
    
    reviews_link = reviews_element.find('a', {'data-testid': 'ux-action'})['href']
    reviews_count = int(reviews_element.find('a', {'data-testid': 'ux-action'}).text.strip().split()[2])
    if reviews_count % 10 == 0:
        pages_count = int(reviews_count/10)
    else:
        pages_count = int(reviews_count/10)+1
    pages_list = list()
    
    for i in range(pages_count):
        page = reviews_link + "&pgn=" + str(i+1)
        response = requests.get(page)
        
        html_content = response.content

        # Create a BeautifulSoup object
        soup = BeautifulSoup(html_content, 'html.parser')

        # Find all the review elements
        review_elements = soup.find_all(class_="ebay-review-section")
        

        # Loop through the review elements and extract the text
        for review_element in review_elements:
            try:
                review_text = review_element.find(class_="review-item-content").get_text(strip=True, separator='\n')
                
            except:
                review_text = ""
                pass
            try:
                review_title = review_element.find(class_="review-item-title").get_text(strip=True, separator='\n')
            except:
                review_title = ""
                pass
            results.append({'Product Title': product_title, 'Condition': condition, 'Price': price, 'Seller': seller, 
                            'Review': review_text, 'Review Title': review_title})

df = pd.DataFrame(results)
df
# Out:
#                                       Product Title Condition    Price  \
# 0   Apple iPhone 12 - 64GB - Black - Unlocked - NEW       New  £155.00
# 1   Apple iPhone 12 - 64GB - Black - Unlocked - NEW       New  £155.00
# 2   Apple iPhone 12 - 64GB - Black - Unlocked - NEW       New  £155.00
# 3   Apple iPhone 12 - 64GB - Black - Unlocked - NEW       New  £155.00
# 4   Apple iPhone 12 - 64GB - Black - Unlocked - NEW       New  £155.00
# ..                                              ...       ...      ...
# 56  Apple iPhone 12 - 64GB - Black - Unlocked - NEW       New  £155.00
# 57  Apple iPhone 12 - 64GB - Black - Unlocked - NEW       New  £155.00
# 58  Apple iPhone 12 - 64GB - Black - Unlocked - NEW       New  £155.00
# 59  Apple iPhone 12 - 64GB - Black - Unlocked - NEW       New  £155.00
# 60  Apple iPhone 12 - 64GB - Black - Unlocked - NEW       New  £155.00
#
#           Seller                                             Review  \
# 0   mark-kathryn  Bit smaller with same screen size at the 11. W...
# 1   mark-kathryn  The battery quality is not the best my I phone...
# 2   mark-kathryn  Excellent phone, great camera, battery could l...
# 3   mark-kathryn  Solid, speedy, reliable iPhone.\nExcellent fea...
# 4   mark-kathryn        Easy to use and fast and has great features
# ..           ...                                                ...
# 56  mark-kathryn                                    Very good value
# 57  mark-kathryn                                              brill
# 58  mark-kathryn                           Feels nice to use, sleek
# 59  mark-kathryn                                  Brilliant product
# 60  mark-kathryn                                     Awesome gadget
#
#                          Review Title
# 0   Not much different from iPhone 11
# 1                          I phone 12
# 2                        Excellent...
# 3                   Good mobile phone
# 4                Easy to use and fast
# ..                                ...
# 56                          iPhone 12
# 57                              brill
# 58                 Amazing, nice feel
# 59                          Excellent
# 60                          iPhone 12
#
# [61 rows x 6 columns]

# %%
df.iloc[12]
# Out:
# Product Title    Apple iPhone 12 - 64GB - Black - Unlocked - NEW
# Condition                                                    New
# Price                                                    £155.00
# Seller                                              mark-kathryn
# Review
# Name: 12, dtype: object

# %%
import requests
from bs4 import BeautifulSoup

# Define the URL
url = "https://www.ebay.co.uk/itm/404561506329?epid=7052775937&hash=item5e31beb019:g:pjUAAOSwD4hlMjfM&amdata=enc%3AAQAIAAAA0DS%2BHBZXg%2B91AMPMNuaKmvaXfniK6GThHnlzWqGxFS00G3AeFiUwVKcEPoUKKMQaoWzrd%2FEarjQMhsp02qIWlAHYdeefYx6%2FngteWe%2FMIKqtkb2NrYv0tA%2F9SSWVw4fCf96eLMjYZ3EtwnCBhcCsG9VSaLciCNF1lCOhHmlE1Jjw1BpZN8eE87c1hItIlCmBeaCPABvpqR7xsM7Z9I4fJI2GTn4q7Rgw30dAEO5m3Y3O%2FVyPIYCYZHtnR7JUtOF5nAxRRopJpAwBrAszQsR6eqI%3D%7Ctkp%3ABFBMqN6U1eti"

# Send a request to the URL and get the content
response = requests.get(url)
html_content = response.content

# Create a BeautifulSoup object
soup = BeautifulSoup(html_content, 'html.parser')

# Find the element with class "ux-textspans" and get its text
element = soup.find(class_="ux-textspans")
text = element.text.strip()

print(text)

# %%
import requests
from bs4 import BeautifulSoup

# Define the URL
url = "https://www.ebay.co.uk/urw/Apple-iPhone-SE-3rd-Gen-64GB-Midnight-Unlocked-/product-reviews/7052775937?_itm=404561506329"

# Send a request to the URL and get the content
response = requests.get(url)
html_content = response.content

# Create a BeautifulSoup object
soup = BeautifulSoup(html_content, 'html.parser')

# Find all the review elements
review_elements = soup.find_all(class_="ebay-review-section-r")

# Loop through the review elements and extract the text
for review_element in review_elements:
    review_text = review_element.find(class_="review-item-content").get_text(strip=True, separator='\n')
    print(review_text)
    print("="*50)
# Out:
# My wife likes to hang onto things and is not one for unnecessary change, so when the battery of her iPhone 6 suddenly failed I looked for a more up-to-date replacement. This pre-owned device has provi
# ded a useful and workable replacement, and I am happy with the purchase.
# This iPhone SE 2020 is a good replacement. The size is the same as the iPhone 6, the battery life has a modest improvement, it fits her previous phone case although the camera lens is not in exactly the same place. There is also the improvement gained from a hardware upgrade. My wife does not push the technology so for her the upgrade appears as an improvement in run-time when looking at TicTok. She also noticed an improvement in the quality of photos after I modified her phone-case so that the lens was not obscured. There are no complaints and that is all I wanted.
# This iPhone SE 2020 has a small physical size, so if you are looking for a 'phone' without a massive screen this is a good choice. The 'home' button is no longer a physical switch, it has a haptic system which simulates the 'click' and works quite well.
# Migrating from the old phone was a breeze thanks to Apple's tool which is intended to help you upgrade your phone. The thing you need to know, and I discovered this by trial and error, is that you must put your SIM into the new phone before you start the migration otherwise things do not happen.
# Read full review...
# ==================================================
# good at the discount price paid, has excellent battery life and is just the right size unless you need a giant video screen to view things
# ==================================================
# I am pleased with the size of this phone. My previous iPhone 5 was a little bit too small,but the main problem was that the battery capacity was always poor,even from new!  This iPhone se 3rd generati
# on is slightly larger.( I prefer a smaller size for less damage while in my pockets when working etc.) The battery capacity on this iPhone se is a lot better!  I have not had it long but all seems good.
# Read full review...
# ==================================================
# Has the functionality of much more expensive phones but for me being a light user its ideal. It is also smaller than all other phones although I preferred the size of the original SE
# ==================================================
# Compact size, recent iOS, 5G, same case as earlier model.  Mine was flawless, with 100% battery health.
# ==================================================
# This is an upgrade from the IPhone 5 se.  I’m pleased with the slightly larger size and it will still fit in pockets.  It charges quickly and so far has been an excellent choice.
# ==================================================
# It has the basic electronics of an iphone 13 (albeit without the higher quality camera) set inside
# a 4.7" case for compactness. Is 5G ready with 64gb on board
# ==================================================
# iPhone at a sensible price. It is the same sort of size as an iPhone 7. Works perfectly and has good battery life. Very highly recommended from this supplier.
# ==================================================
# still has home button and compact with up todate camera
# ==================================================
# Great IPhone
# Battery life lasts a bit longer than my previous  iPhone but could be better.
# Otherwise a brilliant phone and  about  the same size as an iPhone 7 Plus so not too big.
# ==================================================

# %%
import requests
from bs4 import BeautifulSoup

# Define the URL
url = "https://www.ebay.co.uk/itm/404561506329?epid=7052775937&hash=item5e31beb019:g:pjUAAOSwD4hlMjfM&amdata=enc%3AAQAIAAAA0DS%2BHBZXg%2B91AMPMNuaKmvaXfniK6GThHnlzWqGxFS00G3AeFiUwVKcEPoUKKMQaoWzrd%2FEarjQMhsp02qIWlAHYdeefYx6%2FngteWe%2FMIKqtkb2NrYv0tA%2F9SSWVw4fCf96eLMjYZ3EtwnCBhcCsG9VSaLciCNF1lCOhHmlE1Jjw1BpZN8eE87c1hItIlCmBeaCPABvpqR7xsM7Z9I4fJI2GTn4q7Rgw30dAEO5m3Y3O%2FVyPIYCYZHtnR7JUtOF5nAxRRopJpAwBrAszQsR6eqI%3D%7Ctkp%3ABFBMqN6U1eti"

# Send a request to the URL and get the content
response = requests.get(url)
html_content = response.content

# Create a BeautifulSoup object
soup = BeautifulSoup(html_content, 'html.parser')

# Find the <a> element and extract the "href" attribute
link = soup.find('a')['href']

print(link)
# Out:
# #mainContent

# %%
<div class="x-review-details__allreviews"><a href="https://www.ebay.co.uk/urw/Apple+iPhone+SE+3rd+Gen.+-+64GB+-+Midnight+%28Unlocked%29/product-reviews/7052775937?_itm=404561506329" data-testid="ux-action" _sp="p4429486.m3946.l6846" data-vi-tracking="{&quot;eventFamily&quot;:&quot;ITM&quot;,&quot;eventAction&quot;:&quot;ACTN&quot;,&quot;actionKind&quot;:&quot;CLICK&quot;,&quot;operationId&quot;:&quot;4429486&quot;,&quot;flushImmediately&quot;:false,&quot;eventProperty&quot;:{&quot;parentrq&quot;:&quot;d2a3eb4bd2141ac3&quot;,&quot;pageci&quot;:&quot;3f51ad67-d172-40b8-973e-3022e919123b&quot;,&quot;moduledtl&quot;:&quot;mi:3946|li:6846&quot;,&quot;sid&quot;:&quot;p4429486.m3946.l6846&quot;}}"><span class="ux-textspans">See all 50 reviews</span></a></div>
